# %%
vgg16
vgg19
resnet
inception(google net)
mobile net
nasnet
efficient net

# %%
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications import ResNet50

# %%
from tensorflow.keras.preprocessing import image

# %%
from tensorflow.keras.applications.vgg16 import preprocess_input, decode_predictions

# %%
import numpy as np

# %%
model = VGG16(weights='imagenet')
# Out:
# ...
# 553467096/553467096 [==============================] - 19s 0us/step

# %%
img_path = "/content/drive/MyDrive/FSDS2.0/data/cat-dog/dog1.jpg"

# %%
img = image.load_img(img_path, target_size=(224, 224))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
img = image.img_to_array(img)

# %%
img.shape
# Out:
# (224, 224, 3)

# %%
img=np.expand_dims(img, axis=0)

# %%
img.shape
# Out:
# (1, 224, 224, 3)

# %%
prediction=model.predict(img)
# Out:
# 1/1 [==============================] - 0s 18ms/step

# %%
decode_predictions(prediction)
# Out:
# ...
# 35363/35363 [==============================] - 0s 3us/step
# [[('n02093428', 'American_Staffordshire_terrier', 0.9508037),
#   ('n02093256', 'Staffordshire_bullterrier', 0.049178407),
#   ('n02108089', 'boxer', 7.316862e-06),
#   ('n02109047', 'Great_Dane', 3.3681629e-06),
#   ('n02092339', 'Weimaraner', 3.3183105e-06)]]

# %%
model2 = ResNet50(weights='imagenet')
# Out:
# ...
# 102967424/102967424 [==============================] - 4s 0us/step

# %%
img = preprocess_input(img)

# %%
prediction=model2.predict(img)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
decode_predictions(prediction)
# Out:
# [[('n02093256', 'Staffordshire_bullterrier', 0.5710645),
#   ('n02093428', 'American_Staffordshire_terrier', 0.42820874),
#   ('n02108089', 'boxer', 0.0005721801),
#   ('n02087394', 'Rhodesian_ridgeback', 7.4930824e-05),
#   ('n02108422', 'bull_mastiff', 4.2467378e-05)]]

# %%
img2 = "/content/drive/MyDrive/FSDS2.0/data/cat-dog/t_photo.jpg"
img_ = image.load_img(img2, target_size=(224, 224))
img_ = image.img_to_array(img_)
img_ = np.expand_dims(img_, axis=0)

# %%
img_ = preprocess_input(img_)

# %%
pred = model2.predict(img_)
# Out:
# 1/1 [==============================] - 0s 33ms/step

# %%
decode_predictions(pred)
# Out:
# [[('n03788195', 'mosque', 0.8061845),
#   ('n03877845', 'palace', 0.17312089),
#   ('n03447447', 'gondola', 0.009908846),
#   ('n04523525', 'vault', 0.0027193301),
#   ('n03781244', 'monastery', 0.0023568857)]]

# %% [markdown]
# ![image.png](data:image/png;base64,...)
